# %% [markdown]
# <a href="https://colab.research.google.com/github/KaushalKumar-100/machine_learning_module/blob/main/Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
a=plt.scatter(df["cgpa"],df["iq"],c=df["placement"])
plt.title("placement vs cgpa and iq")
plt.xlabel("cgpa")
plt.ylabel("iq")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1742483062.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from sklearn.model_selection import train_test_split
X=df[["cgpa","iq"]]
y=df["placement"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred=lr.predict(X_test)

# %%
X_test=np.array(X_test)

# %%
y_test
# Out:
# 26    1
# 80    0
# 82    1
# 68    0
# 77    1
# 37    1
# 3     1
# 55    1
# 20    1
# 17    0
# 72    1
# 24    0
# 71    1
# 87    1
# 89    0
# 29    1
# 9     0
# 67    0
# 42    1
# 94    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score,r2_score
accuracy_score(y_test,lr.predict(X_test))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0.95

# %%
RFG=RandomForestClassifier()
RFG.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
x=RFG.predict(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy_score(y_test,RFG.predict(X_test))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_test,y_test.values,clf=RFG,legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
import joblib

# %%
joblib.dump(RFG,"placement.joblib")
# Out:
# ['placement.joblib']

# %%
from sklearn.datasets import load_iris

# %%
df3=load_iris(as_frame=True).frame

# %%
df3
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df3.dropna()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df3.drop(columns=["sepal width (cm)","petal width (cm)"])
# Out:
#      sepal length (cm)  petal length (cm)  target
# 0                  5.1                1.4       0
# 1                  4.9                1.4       0
# 2                  4.7                1.3       0
# 3                  4.6                1.5       0
# 4                  5.0                1.4       0
# ..                 ...                ...     ...
# 145                6.7                5.2       2
# 146                6.3                5.0       2
# 147                6.5                5.2       2
# 148                6.2                5.4       2
# 149                5.9                5.1       2
#
# [150 rows x 3 columns]
